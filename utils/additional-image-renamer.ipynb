# %%
from os import listdir
import os

# %%
positive = [1, 3, 6, 17, 19, 22, 23, 26, 29, 30, 32, 33, 34, 42, 44, 45, 46, 47, 49, 53, 55, 56, 57, 59, 63, 64, 65, 66, 68, 69, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 85, 86, 87, 89, 91, 94, 97, 98, 99, 101, 104, 109, 110, 112, 121, 126, 127, 133, 136, 137, 138, 140, 141, 145, 146, 147, 156, 158, 161, 164, 165, 166, 168, 169, 171, 172, 173, 175, 176, 182, 183, 184, 193, 195, 203, 204, 206, 207, 208, 212, 221, 222]

negative = [2, 5, 7, 8, 10, 11, 12, 13, 14, 20, 24, 25, 28, 31, 35, 36, 37, 38, 39, 41, 43, 48, 51, 52, 54, 58, 60, 61, 71, 88, 93, 103, 105, 114, 116, 117, 119, 120, 122, 123, 124, 125, 132, 135, 139, 142, 143, 144, 149, 151, 152, 153, 154, 155, 157, 159, 163, 167, 170, 174, 177, 178, 179, 180, 181, 185, 186, 187, 188, 189, 190, 191, 192, 194, 196, 197, 198, 199, 200, 201, 202, 205, 209, 210, 211, 213, 214, 215, 216, 217, 218, 219, 220, 223
]


researcher_path = '../dataset/additional/PENELITI'
for i in listdir(researcher_path):
    if i.endswith('.jpg'):
        filename_without_ext = i.split('.')[0]
        filename_number = filename_without_ext.split(' ')[1]
        filename = ""
        if int(filename_number) in positive:
            filename = filename_without_ext + '+' + '.jpg'
        if int(filename_number) in negative:
            filename = filename_without_ext + '-' + '.jpg'

        # rename the file
        if filename != "":
            old_file_path = researcher_path + '/' + i
            new_file_path = researcher_path + '/' + filename
            print(f"Renaming {old_file_path} to {new_file_path}")
            os.rename(old_file_path, new_file_path)
# Out:
# Renaming ./dataset/additional/PENELITI/OD 1.jpg to ./dataset/additional/PENELITI/OD 1+.jpg
# Renaming ./dataset/additional/PENELITI/OD 10.jpg to ./dataset/additional/PENELITI/OD 10-.jpg
# Renaming ./dataset/additional/PENELITI/OD 101.jpg to ./dataset/additional/PENELITI/OD 101+.jpg
# Renaming ./dataset/additional/PENELITI/OD 103.jpg to ./dataset/additional/PENELITI/OD 103-.jpg
# Renaming ./dataset/additional/PENELITI/OD 104.jpg to ./dataset/additional/PENELITI/OD 104+.jpg
# Renaming ./dataset/additional/PENELITI/OD 105.jpg to ./dataset/additional/PENELITI/OD 105-.jpg
# Renaming ./dataset/additional/PENELITI/OD 109.jpg to ./dataset/additional/PENELITI/OD 109+.jpg
# Renaming ./dataset/additional/PENELITI/OD 11.jpg to ./dataset/additional/PENELITI/OD 11-.jpg
# Renaming ./dataset/additional/PENELITI/OD 110.jpg to ./dataset/additional/PENELITI/OD 110+.jpg
# Renaming ./dataset/additional/PENELITI/OD 112.jpg to ./dataset/additional/PENELITI/OD 112+.jpg
# ...
